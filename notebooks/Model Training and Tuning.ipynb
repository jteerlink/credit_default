# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.abspath("../"))

from src.preprocess import preprocess
from xgboost import plot_importance
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import cross_val_score, StratifiedKFold
import optuna

from sklearn.metrics import roc_auc_score, roc_curve
import xgboost as xgb

# %% [markdown]
# # Approach
#
# 1. Establish baseline model with default hyperparameters
# 2. Select which hp to tune focusing on those that prevent overfitting since we have thin data
# 3. run tuning using optuna
# 4. evaluate performance using key metrics: AUC, Gini index
#
#
# ## See summary in model validation notebook

# %%
#load data into dataframe
filepath = '../data/raw_data.csv'
raw_df = pd.read_csv(filepath)

# %%
final_df = preprocess(raw_df)

# %%
# from feature selection notebook
selected_features=['OverdraftTotal',
 'BalanceAverage',
 'TotalCash',
 'CurrentBalance',
 'CurrentBalance_missing',
 'NumberOfMatches',
 'AverageMonthlyDiscretionarySpend',
 'LastRepaymentAmount',
 'ErrorRate',
 'NegativeBalanceCount',
 'SavingsAccountCount',
 'AveragePotentialMonthlyIncome',
 'CheckingAccountCount',
 'AverageNumberOfTransactionsADay',
 'TotalHistoryInDays',
 'Paycheck',
 'HasEmpowerBanking',
 'IsNameBased',
 'BalanceAbove100L30Count',
 'AverageMonthlySpend',
 'AverageMonthlyIncome',
 'AverageNumberOfTransactionsADayPrimaryChecking',
 'PaycheckModel_Tagging',
 'od_per_30d',
 'CreditAccounts',
 'BalanceMin',
 'OverdraftCount',
 'TotalAssets',
 'PaycheckModel_DeepSearch',
 'dep_wd_ratio',
 'bal_vol_index',
 'PaycheckModel_BruteForce',
 'OutstandingCreditDebtWherePayingInterest',
 'LatefeesTotalCount',
 'LatefeesCount',
 'DefaultedAdvances']

# %%
final_df = final_df[selected_features]

X_df = final_df.drop('DefaultedAdvances', axis=1)
y = final_df['DefaultedAdvances']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_df, y, test_size=0.20, random_state=75454)

# %%
model = xgb.XGBClassifier(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_proba = model.predict_proba(X_test)

auc = roc_auc_score(y_test, y_pred_proba[:,1])

gini = 2 * auc - 1

print(f'Baseline model AUC: {auc:.4f}')
print(f'Baseline model Gini: {gini:.4f}')
# Out:
# Baseline model AUC: 0.6858
# Baseline model Gini: 0.3715

# %% [markdown]
# ## Hyperparameter tuning

# %%
def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 2, 6),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5, step=0.1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 10, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1, 100, log=True),
        'subsample': trial.suggest_float('subsample', 0.3, 0.9, step=0.1),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.9, step=0.1),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.3, 1.0, step=0.1),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'verbosity': 0,
    }


    clf = xgb.XGBClassifier(**params)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    score = cross_val_score(clf, X_train, y_train, cv=cv, scoring="roc_auc").mean()
    return score

# Run the optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30, timeout=300, show_progress_bar=True)

# Show results
print("Best trial:")
trial = study.best_trial
print(f"  AUC: {trial.value}")
print("  Best hyperparameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-05-22 08:02:52,602] A new study created in memory with name: no-name-cb775c39-416f-4d41-87db-9ac9b8993a8b
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-05-22 08:02:57,727] Trial 0 finished with value: 0.7165011066476369 and parameters: {'max_depth': 6, 'min_child_weight': 7, 'gamma': 0.0, 'reg_alpha': 0.33134671770049745, 'reg_lambda': 30.71361644959434, 'subsample': 0.7, 'colsample_bytree': 0.8, 'colsample_bylevel': 0.5, 'learning_rate': 0.02950524236994106, 'n_estimators': 900}. Best is trial 0 with value: 0.7165011066476369.
# [I 2025-05-22 08:02:58,006] Trial 1 finished with value: 0.7073555980530564 and parameters: {'max_depth': 2, 'min_child_weight': 9, 'gamma': 3.0, 'reg_alpha': 0.5127437862366949, 'reg_lambda': 5.853543617162443, 'subsample': 0.7, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.5, 'learning_rate': 0.07353121028669214, 'n_estimators': 100}. Best is trial 0 with value: 0.7165011066476369.
# [I 2025-05-22 08:02:59,549] Trial 2 finished with value: 0.71715677034946 and parameters: {'max_depth': 5, 'min_child_weight': 10, 'gamma': 4.6000000000000005, 'reg_alpha': 2.965991861317631, 'reg_lambda': 6.561356486648746, 'subsample': 0.8, 'colsample_bytree': 0.6000000000000001, 'colsample_bylevel': 0.9000000000000001, 'learning_rate': 0.03044485307146046, 'n_estimators': 700}. Best is trial 2 with value: 0.71715677034946.
# [I 2025-05-22 08:03:00,021] Trial 3 finished with value: 0.712061176359513 and parameters: {'max_depth': 2, 'min_child_weight': 4, 'gamma': 1.0, 'reg_alpha': 0.5890033948444056, 'reg_lambda': 12.472470285836433, 'subsample': 0.5, 'colsample_bytree': 0.8, 'colsample_bylevel': 0.8, 'learning_rate': 0.050841518501422205, 'n_estimators': 200}. Best is trial 2 with value: 0.71715677034946.
# [I 2025-05-22 08:03:01,932] Trial 4 finished with value: 0.7179519189298871 and parameters: {'max_depth': 6, 'min_child_weight': 5, 'gamma': 1.4000000000000001, 'reg_alpha': 0.033493091498485776, 'reg_lambda': 4.075317941995525, 'subsample': 0.3, 'colsample_bytree': 0.3, 'colsample_bylevel': 0.5, 'learning_rate': 0.014559079843057453, 'n_estimators': 500}. Best is trial 4 with value: 0.7179519189298871.
# [I 2025-05-22 08:03:03,037] Trial 5 finished with value: 0.7010137692267276 and parameters: {'max_depth': 6, 'min_child_weight': 1, 'gamma': 2.8000000000000003, 'reg_alpha': 0.03878971923946314, 'reg_lambda': 2.45226339269527, 'subsample': 0.7, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.18746127228349718, 'n_estimators': 600}. Best is trial 4 with value: 0.7179519189298871.
# [I 2025-05-22 08:03:05,376] Trial 6 finished with value: 0.7211414077669038 and parameters: {'max_depth': 6, 'min_child_weight': 2, 'gamma': 0.6000000000000001, 'reg_alpha': 0.017472050642446293, 'reg_lambda': 96.51447290203181, 'subsample': 0.3, 'colsample_bytree': 0.8, 'colsample_bylevel': 0.5, 'learning_rate': 0.06975185921069735, 'n_estimators': 500}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:06,395] Trial 7 finished with value: 0.7141397320814276 and parameters: {'max_depth': 6, 'min_child_weight': 2, 'gamma': 1.9000000000000001, 'reg_alpha': 6.584464025535931, 'reg_lambda': 79.63105102369563, 'subsample': 0.9, 'colsample_bytree': 0.6000000000000001, 'colsample_bylevel': 0.5, 'learning_rate': 0.15638102853933988, 'n_estimators': 600}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:08,029] Trial 8 finished with value: 0.7168290065363742 and parameters: {'max_depth': 3, 'min_child_weight': 4, 'gamma': 4.6000000000000005, 'reg_alpha': 0.3001128923253909, 'reg_lambda': 1.697232054323939, 'subsample': 0.8, 'colsample_bytree': 0.3, 'colsample_bylevel': 0.5, 'learning_rate': 0.036184154697869494, 'n_estimators': 1000}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:09,042] Trial 9 finished with value: 0.7164727834466986 and parameters: {'max_depth': 3, 'min_child_weight': 9, 'gamma': 2.8000000000000003, 'reg_alpha': 1.1337621303422594, 'reg_lambda': 8.91783111737795, 'subsample': 0.8, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.7, 'learning_rate': 0.02054781670920597, 'n_estimators': 400}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:10,053] Trial 10 finished with value: 0.7200079756461204 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'gamma': 0.8, 'reg_alpha': 0.01888543535155111, 'reg_lambda': 90.09018180676252, 'subsample': 0.3, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.3, 'learning_rate': 0.09774909978586548, 'n_estimators': 300}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:11,086] Trial 11 finished with value: 0.7200107533942118 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'gamma': 0.0, 'reg_alpha': 0.016804673114063463, 'reg_lambda': 95.54323173145438, 'subsample': 0.3, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.3, 'learning_rate': 0.09450361516805565, 'n_estimators': 300}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:12,472] Trial 12 finished with value: 0.7130576384680071 and parameters: {'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.1, 'reg_alpha': 0.07608224314031874, 'reg_lambda': 34.88603158832832, 'subsample': 0.4, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.3, 'learning_rate': 0.10941529382931088, 'n_estimators': 400}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:15,434] Trial 13 finished with value: 0.6910682286641727 and parameters: {'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.5, 'reg_alpha': 0.01171420821637664, 'reg_lambda': 39.0101815027303, 'subsample': 0.5, 'colsample_bytree': 0.8, 'colsample_bylevel': 0.3, 'learning_rate': 0.23999704249586432, 'n_estimators': 800}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:16,689] Trial 14 finished with value: 0.7185878159355843 and parameters: {'max_depth': 5, 'min_child_weight': 6, 'gamma': 1.6, 'reg_alpha': 0.1137377681436331, 'reg_lambda': 21.981407574559714, 'subsample': 0.4, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.4, 'learning_rate': 0.05541145214244408, 'n_estimators': 300}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:17,854] Trial 15 finished with value: 0.7194455116339167 and parameters: {'max_depth': 3, 'min_child_weight': 3, 'gamma': 3.6, 'reg_alpha': 0.09147280150276989, 'reg_lambda': 60.191418585079624, 'subsample': 0.4, 'colsample_bytree': 0.7, 'colsample_bylevel': 1.0, 'learning_rate': 0.12632641087738483, 'n_estimators': 500}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:18,297] Trial 16 finished with value: 0.7145846509023014 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'gamma': 2.2, 'reg_alpha': 0.010431638116408416, 'reg_lambda': 17.696082631593566, 'subsample': 0.3, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.4, 'learning_rate': 0.07399752158955282, 'n_estimators': 100}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:19,757] Trial 17 finished with value: 0.7079215102301157 and parameters: {'max_depth': 5, 'min_child_weight': 7, 'gamma': 1.1, 'reg_alpha': 0.03157542976223427, 'reg_lambda': 55.83545559350701, 'subsample': 0.5, 'colsample_bytree': 0.8, 'colsample_bylevel': 0.7, 'learning_rate': 0.010091717617902942, 'n_estimators': 300}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:21,667] Trial 18 finished with value: 0.7021648979781187 and parameters: {'max_depth': 3, 'min_child_weight': 4, 'gamma': 0.5, 'reg_alpha': 0.14858829882876012, 'reg_lambda': 97.7968994097646, 'subsample': 0.6000000000000001, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.4, 'learning_rate': 0.25540693716079266, 'n_estimators': 700}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:23,328] Trial 19 finished with value: 0.7201403062123065 and parameters: {'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.0, 'reg_alpha': 0.04525146788205811, 'reg_lambda': 49.385012132620965, 'subsample': 0.3, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.0487483428690572, 'n_estimators': 400}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:24,327] Trial 20 finished with value: 0.7127939515475276 and parameters: {'max_depth': 5, 'min_child_weight': 1, 'gamma': 3.6, 'reg_alpha': 0.0416494657474987, 'reg_lambda': 52.28845852285986, 'subsample': 0.4, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.0418078999572726, 'n_estimators': 400}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:25,118] Trial 21 finished with value: 0.7145882615522329 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.30000000000000004, 'reg_alpha': 0.018858168877542207, 'reg_lambda': 61.80135520483747, 'subsample': 0.3, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.07245383392526997, 'n_estimators': 200}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:26,707] Trial 22 finished with value: 0.7189900883131203 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'gamma': 0.0, 'reg_alpha': 0.018908298063201885, 'reg_lambda': 23.776467886175066, 'subsample': 0.3, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.8, 'learning_rate': 0.05672520004304294, 'n_estimators': 500}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:28,370] Trial 23 finished with value: 0.7191959102005028 and parameters: {'max_depth': 6, 'min_child_weight': 1, 'gamma': 0.7000000000000001, 'reg_alpha': 0.05831659036836668, 'reg_lambda': 96.35452544020085, 'subsample': 0.4, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.4, 'learning_rate': 0.08796618703167675, 'n_estimators': 400}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:29,048] Trial 24 finished with value: 0.7150180436673761 and parameters: {'max_depth': 4, 'min_child_weight': 3, 'gamma': 1.3, 'reg_alpha': 0.18750467385221248, 'reg_lambda': 41.83811093182213, 'subsample': 0.3, 'colsample_bytree': 0.6000000000000001, 'colsample_bylevel': 0.7, 'learning_rate': 0.14062403828846468, 'n_estimators': 200}. Best is trial 6 with value: 0.7211414077669038.
# [I 2025-05-22 08:03:31,126] Trial 25 finished with value: 0.721482327522591 and parameters: {'max_depth': 5, 'min_child_weight': 5, 'gamma': 0.5, 'reg_alpha': 0.021948961509975343, 'reg_lambda': 67.87330560039315, 'subsample': 0.5, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.024239058326395235, 'n_estimators': 600}. Best is trial 25 with value: 0.721482327522591.
# [I 2025-05-22 08:03:33,766] Trial 26 finished with value: 0.7211134383014784 and parameters: {'max_depth': 6, 'min_child_weight': 5, 'gamma': 1.6, 'reg_alpha': 0.05576030356247852, 'reg_lambda': 28.01278527500301, 'subsample': 0.6000000000000001, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.021799592256519756, 'n_estimators': 700}. Best is trial 25 with value: 0.721482327522591.
# [I 2025-05-22 08:03:36,518] Trial 27 finished with value: 0.7202746143450759 and parameters: {'max_depth': 6, 'min_child_weight': 6, 'gamma': 1.8, 'reg_alpha': 0.026419876539626234, 'reg_lambda': 14.32379118190513, 'subsample': 0.6000000000000001, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.8, 'learning_rate': 0.019839686584507778, 'n_estimators': 700}. Best is trial 25 with value: 0.721482327522591.
# [I 2025-05-22 08:03:38,815] Trial 28 finished with value: 0.7199652264120964 and parameters: {'max_depth': 6, 'min_child_weight': 5, 'gamma': 2.2, 'reg_alpha': 0.07628750998576529, 'reg_lambda': 29.879354020219306, 'subsample': 0.5, 'colsample_bytree': 0.3, 'colsample_bylevel': 0.7, 'learning_rate': 0.021941226852263657, 'n_estimators': 800}. Best is trial 25 with value: 0.721482327522591.
# [I 2025-05-22 08:03:42,520] Trial 29 finished with value: 0.7194604500741593 and parameters: {'max_depth': 6, 'min_child_weight': 7, 'gamma': 0.9, 'reg_alpha': 0.16219867527778672, 'reg_lambda': 29.92420256076037, 'subsample': 0.6000000000000001, 'colsample_bytree': 0.4, 'colsample_bylevel': 0.6000000000000001, 'learning_rate': 0.026221970732518477, 'n_estimators': 900}. Best is trial 25 with value: 0.721482327522591.
# Best trial:
#   AUC: 0.721482327522591
#   Best hyperparameters:
#     max_depth: 5
#     min_child_weight: 5
#     gamma: 0.5
#     reg_alpha: 0.021948961509975343
#     reg_lambda: 67.87330560039315
#     subsample: 0.5
#     colsample_bytree: 0.4
#     colsample_bylevel: 0.6000000000000001
#     learning_rate: 0.024239058326395235
#     n_estimators: 600

# %%
best_params = study.best_params

# %%
final_model = xgb.XGBClassifier(
        **best_params,        
    )
final_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.6000000000000001, colsample_bynode=None,
#               colsample_bytree=0.4, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=0.5, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.024239058326395235, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=600, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_proba = final_model.predict_proba(X_test)

auc = roc_auc_score(y_test, y_pred_proba[:,1])

gini = 2 * auc - 1

print(f'Tuned model AUC: {auc:.4f}')
print(f'Tuned model Gini: {gini:.4f}')
# Out:
# Tuned model AUC: 0.7201
# Tuned model Gini: 0.4401

# %%
val_df = pd.DataFrame({'y_true':y_test, 'y_pred':y_pred_proba[:,1]})

# %%
val_df.to_csv('../data/val_predictions.csv',index=False)

# %%
final_model.save_model('../artifacts/final_model.json')
